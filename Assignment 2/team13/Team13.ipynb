# %%
# !wget https://assignmentpremnathsmu.s3.amazonaws.com/crimes.csv
# Out:
# converted 'https://assignmentpremnathsmu.s3.amazonaws.com/crimes.csv' (ANSI_X3.4-1968) -> 'https://assignmentpremnathsmu.s3.amazonaws.com/crimes.csv' (UTF-8)
# --2015-11-14 06:19:43--  https://assignmentpremnathsmu.s3.amazonaws.com/crimes.csv
# Resolving assignmentpremnathsmu.s3.amazonaws.com (assignmentpremnathsmu.s3.amazonaws.com)... 54.231.241.140
# Connecting to assignmentpremnathsmu.s3.amazonaws.com (assignmentpremnathsmu.s3.amazonaws.com)|54.231.241.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1395165768 (1.3G) [application/octet-stream]
# Saving to: 'crimes.csv'
#
# crimes.csv          100%[=====================>]   1.30G  5.33MB/s   in 4m 18s
#
# 2015-11-14 06:24:01 (5.16 MB/s) - 'crimes.csv' saved [1395165768/1395165768]

# %%
localfile = "crimes.csv"
myfile = open( localfile )
count = 0
for line in myfile:
   count += 1
numRows = count
df = pd.read_csv(localfile, nrows=numRows)
df.head()
barhn=df.groupby(['Primary Type','Year'])['Year'].count()
print (barhn)
# Out:
# Primary Type       Year
# ARSON              2001     1010
#                    2002     1032
#                    2003      955
#                    2004      778
#                    2005      691
#                    2006      726
#                    2007      712
#                    2008      644
#                    2009      616
#                    2010      522
#                    2011      504
#                    2012      469
#                    2013      364
#                    2014      398
#                    2015      364
# ASSAULT            2001    31383
#                    2002    31521
#                    2003    29477
#                    2004    28850
#                    2005    27066
#                    2006    25945
#                    2007    26314
#                    2008    25447
#                    2009    22861
#                    2010    21535
#                    2011    20410
#                    2012    19897
# ...

# %%
myfile = open( localfile )
count = 0
for line in myfile:
   count += 1
print("There were {} lines in the file.".format(count))
# Out:
# There were 5926427 lines in the file.

# %%
import matplotlib.pyplot as plt
import pandas as pd
plt.figure()
barhn.plot(kind='bar', stacked=True);
